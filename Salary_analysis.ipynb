# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\radha\Downloads\Salaries.csv\Salaries.csv")
df
# Out:
# C:\Users\radha\AppData\Local\Temp\ipykernel_28348\971495969.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\radha\Downloads\Salaries.csv\Salaries.csv")
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# ...

# %%
df.head(5)
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
df.describe()
# Out:
#                   Id       TotalPay  TotalPayBenefits           Year  Notes
# count  148654.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    74327.500000   74768.321972      93692.554811    2012.522643    NaN
# std     42912.857795   50517.005274      62793.533483       1.117538    NaN
# min         1.000000    -618.130000       -618.130000    2011.000000    NaN
# 25%     37164.250000   36168.995000      44065.650000    2012.000000    NaN
# 50%     74327.500000   71426.610000      92404.090000    2013.000000    NaN
# 75%    111490.750000  105839.135000     132876.450000    2014.000000    NaN
# max    148654.000000  567595.430000     567595.430000    2014.000000    NaN

# %%
df['BasePay'] = df['BasePay'].replace('Not Provided',np.nan)
df['BasePay'].astype(float).describe()
# Out:
# count    148045.000000
# mean      66325.448840
# std       42764.635495
# min        -166.010000
# 25%       33588.200000
# 50%       65007.450000
# 75%       94691.050000
# max      319275.010000
# Name: BasePay, dtype: float64

# %%
df['BasePay'].describe()
# Out:
# count     148045.0
# unique    109899.0
# top            0.0
# freq         875.0
# Name: BasePay, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df.drop(['Id','Notes', 'Agency',
       'Status'],axis = 1,inplace = True)

# %%
df.head(5)
# Out:
#         EmployeeName                                        JobTitle  \
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
df['EmployeeName'].value_counts().head(10).plot(kind = 'bar')
# Out:
# <Axes: xlabel='EmployeeName'>

# %%
df[df['JobTitle'].str.contains("CAPTAIN",case = False)].count()
# Out:
# EmployeeName        552
# JobTitle            552
# BasePay             551
# OvertimePay         552
# OtherPay            552
# Benefits            411
# TotalPay            552
# TotalPayBenefits    552
# Year                552
# dtype: int64

# %%
df[df['JobTitle'].str.contains("CAPTAIN",case = False)].count().plot(figsize = (10,10))
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# EmployeeName            0
# JobTitle                0
# BasePay               609
# OvertimePay             0
# OtherPay                0
# Benefits            36159
# TotalPay                0
# TotalPayBenefits        0
# Year                    0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.dropna(how='any',inplace=True)
df
# Out:
#               EmployeeName                      JobTitle    BasePay  \
# 36159       Gary Altenberg  Lieutenant, Fire Suppression  128808.87
# 36160         Gregory Suhr               Chief of Police   302578.0
# 36161           Khoa Trinh   Electronic Maintenance Tech   111921.0
# 36162   Joanne Hayes-White        Chief, Fire Department  296943.01
# 36163    Frederick Binkley     EMT/Paramedic/Firefighter  126863.19
# ...                    ...                           ...        ...
# 148645    Carolyn A Wilson     Human Services Technician       0.00
# 148647      Joann Anderson   Communications Dispatcher 2       0.00
# 148648         Leon Walker                     Custodian       0.00
# 148649       Roy I Tillery                     Custodian       0.00
# 148653           Joe Lopez    Counselor, Log Cabin Ranch       0.00
#
#        OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  Year
# 36159    220909.48  13126.31  44430.12  362844.66         407274.78  2012
# ...

# %%
df.isnull().sum()
# Out:
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# Benefits            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
dup=df.duplicated().any()
dup
# Out:
# np.False_

# %%
df.shape
# Out:
# (111886, 9)

# %%
df.describe()
# Out:
#             TotalPay  TotalPayBenefits           Year
# count  111886.000000     111886.000000  111886.000000
# mean    76128.778458     101243.122968    2013.012093
# std     51269.681584      65248.814471       0.818020
# min      -618.130000       -618.130000    2012.000000
# 25%     37041.205000      49674.847500    2012.000000
# 50%     72628.810000     101967.740000    2013.000000
# 75%    107530.010000     142991.082500    2014.000000
# max    471952.640000     510732.680000    2014.000000

# %%
df.describe()
# Out:
#             TotalPay  TotalPayBenefits           Year
# count  111886.000000     111886.000000  111886.000000
# mean    76128.778458     101243.122968    2013.012093
# std     51269.681584      65248.814471       0.818020
# min      -618.130000       -618.130000    2012.000000
# 25%     37041.205000      49674.847500    2012.000000
# 50%     72628.810000     101967.740000    2013.000000
# 75%    107530.010000     142991.082500    2014.000000
# max    471952.640000     510732.680000    2014.000000

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
df['TotalPay'].head(10).plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df['TotalPayBenefits'].head(10).plot()
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
df1 = df[['OvertimePay','Benefits', 'TotalPay', 'TotalPayBenefits','Year']]
df1.plot(kind = 'hist', x='Year',y= ['TotalPay','TotalPayBenefits'] , subplots = True)
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#       dtype=object)

# %%
df['JobTitle'].str.contains('Lieutenant').sum()
# Out:
# np.int64(986)

# %%
df.isin(['?']).sum()
# Out:
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# Benefits            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# dtype: int64

# %%
df
# Out:
#               EmployeeName                      JobTitle    BasePay  \
# 36159       Gary Altenberg  Lieutenant, Fire Suppression  128808.87
# 36160         Gregory Suhr               Chief of Police   302578.0
# 36161           Khoa Trinh   Electronic Maintenance Tech   111921.0
# 36162   Joanne Hayes-White        Chief, Fire Department  296943.01
# 36163    Frederick Binkley     EMT/Paramedic/Firefighter  126863.19
# ...                    ...                           ...        ...
# 148645    Carolyn A Wilson     Human Services Technician       0.00
# 148647      Joann Anderson   Communications Dispatcher 2       0.00
# 148648         Leon Walker                     Custodian       0.00
# 148649       Roy I Tillery                     Custodian       0.00
# 148653           Joe Lopez    Counselor, Log Cabin Ranch       0.00
#
#        OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  Year
# 36159    220909.48  13126.31  44430.12  362844.66         407274.78  2012
# ...

# %%
df[df['JobTitle']=='Custodian'].head(5)
# Out:
#            EmployeeName   JobTitle   BasePay OvertimePay OtherPay  Benefits  \
# 55797      Jeannie Shen  Custodian  54067.84    12890.29    624.0   29194.0
# 56187  Vallery Williams  Custodian  51502.01         0.0  13856.0   29824.2
# 56411    Walfred Ferrer  Custodian   51502.1      6312.7  6585.35  29703.58
# 56455   Raymond J Huang  Custodian   51492.8    13319.85  1012.85  28098.98
# 56597        Zhen-Li Li  Custodian   51502.0    10109.67  3434.62  28391.69
#
#        TotalPay  TotalPayBenefits  Year
# 55797  67582.13          96776.13  2012
# 56187  65358.01          95182.21  2012
# 56411  64400.15          94103.73  2012
# 56455  65825.50          93924.48  2012
# 56597  65046.29          93437.98  2012

# %%
df.set_index(['JobTitle'])
# Out:
#                                     EmployeeName    BasePay OvertimePay  \
# JobTitle
# Lieutenant, Fire Suppression      Gary Altenberg  128808.87   220909.48
# Chief of Police                     Gregory Suhr   302578.0         0.0
# Electronic Maintenance Tech           Khoa Trinh   111921.0   146415.32
# Chief, Fire Department        Joanne Hayes-White  296943.01         0.0
# EMT/Paramedic/Firefighter      Frederick Binkley  126863.19   192424.49
# ...                                          ...        ...         ...
# Human Services Technician       Carolyn A Wilson       0.00        0.00
# Communications Dispatcher 2       Joann Anderson       0.00        0.00
# Custodian                            Leon Walker       0.00        0.00
# Custodian                          Roy I Tillery       0.00        0.00
# Counselor, Log Cabin Ranch             Joe Lopez       0.00        0.00
#
#                               OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# JobTitle
# ...

# %%
df[df['JobTitle']=='Custodian'].head(5)
# Out:
#            EmployeeName   JobTitle   BasePay OvertimePay OtherPay  Benefits  \
# 55797      Jeannie Shen  Custodian  54067.84    12890.29    624.0   29194.0
# 56187  Vallery Williams  Custodian  51502.01         0.0  13856.0   29824.2
# 56411    Walfred Ferrer  Custodian   51502.1      6312.7  6585.35  29703.58
# 56455   Raymond J Huang  Custodian   51492.8    13319.85  1012.85  28098.98
# 56597        Zhen-Li Li  Custodian   51502.0    10109.67  3434.62  28391.69
#
#        TotalPay  TotalPayBenefits  Year
# 55797  67582.13          96776.13  2012
# 56187  65358.01          95182.21  2012
# 56411  64400.15          94103.73  2012
# 56455  65825.50          93924.48  2012
# 56597  65046.29          93437.98  2012

# %%
df.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
df2 = df[['JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
       'Benefits', 'TotalPay', 'TotalPayBenefits']]

df2[df2['JobTitle']=='Custodian'].head(5).plot(kind = 'bar', figsize=(10,10))
# Out:
# <Axes: >
